# %%
import itc_utils.flight_service as itcfs

readClient = itcfs.get_flight_client()

nb_data_request = {
    'data_name': """Databases for MongoDB_TEST_SALES_shaped""",
    'interaction_properties': {
    }
}

flightInfo = itcfs.get_flight_info(readClient, nb_data_request=nb_data_request)

data_df_1 = itcfs.read_pandas_and_concat(readClient, flightInfo)
data_df_1.head(10)
# Out:
#                   SALEDATE STORELOCATION                       _ID  \
# 0  2014-11-11 02:13:51.893        London  5BD761DCAE323E45A93CCFEE
# 1  2017-08-21 20:38:34.618     San Diego  5BD761DCAE323E45A93CCFF6
# 2  2015-07-22 02:45:20.727        London  5BD761DCAE323E45A93CCFF3
# 3  2014-08-18 04:37:26.849        Denver  5BD761DCAE323E45A93CCFF1
# 4  2017-09-14 10:52:42.206        Denver  5BD761DCAE323E45A93CD008
# 5  2015-01-11 10:46:32.673       Seattle  5BD761DCAE323E45A93CD017
# 6  2016-03-28 00:27:12.457        Denver  5BD761DCAE323E45A93CD003
# 7  2016-04-27 08:09:58.703        London  5BD761DCAE323E45A93CD00F
# 8  2015-10-12 06:34:36.325        London  5BD761DCAE323E45A93CD026
# 9  2016-02-06 09:35:02.820        London  5BD761DCAE323E45A93CD021
#
#                                             CUSTOMER       CUSTOMER_EMAIL  \
# 0  {gender:"F",age:40,email:"pan@cak.zm",satisfac...           pan@cak.zm
# 1  {gender:"F",age:36,email:"gul@waija.nz",satisf...         gul@waija.nz
# ...

# %%
from ibm_watson_studio_lib import access_project_or_space
wslib = access_project_or_space()

import pandas as pd

df_data_1 = pd.read_csv(wslib.mount.get_data_path('Databases for MongoDB_TEST_SALES_shaped'))
df_data_1.head()
# Out:
#                   SALEDATE STORELOCATION                       _ID  \
# 0  2014-11-11 02:13:51.893        London  5BD761DCAE323E45A93CCFEE
# 1  2017-08-21 20:38:34.618     San Diego  5BD761DCAE323E45A93CCFF6
# 2  2015-07-22 02:45:20.727        London  5BD761DCAE323E45A93CCFF3
# 3  2014-08-18 04:37:26.849        Denver  5BD761DCAE323E45A93CCFF1
# 4  2017-09-14 10:52:42.206        Denver  5BD761DCAE323E45A93CD008
#
#                                             CUSTOMER    CUSTOMER_EMAIL  \
# 0  {gender:"F",age:40,email:"pan@cak.zm",satisfac...        pan@cak.zm
# 1  {gender:"F",age:36,email:"gul@waija.nz",satisf...      gul@waija.nz
# 2  {gender:"F",age:49,email:"merto@betosiv.pm",sa...  merto@betosiv.pm
# 3  {gender:"M",age:57,email:"ohaguwu@nufub.gi",sa...  ohaguwu@nufub.gi
# 4  {gender:"F",age:54,email:"civma@rozfon.tr",sat...   civma@rozfon.tr
#
#   CUSTOMER_GENDER  CUSTOMER_SATISFACTION  CUSTOMER_AGE  \
# 0               F                      5            40
# ...

# %%
import time;

# %%
time.sleep(5); print("1 of 5");
# Out:
# wow

# %%
time.sleep(5); print("2 of 5");
# Out:
# 2 of 5

# %%
time.sleep(5); print("3 of 5");
# Out:
# 3 of 5

# %%
time.sleep(5); print("4 of 5");
# Out:
# 4 of 5

# %%
time.sleep(5); print("5 of 5");
# Out:
# 5 of 5

# %%
print("thanks for waiting!!");
# Out:
# thanks for waiting!!
